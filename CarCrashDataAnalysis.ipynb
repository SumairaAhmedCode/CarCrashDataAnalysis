# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('Motor_Crash.csv')
# Out:
# C:\Users\shpar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# ...

# %%
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
#df=df.drop(['LATITUDE','LONGITUDE'],axis =1)
#df.drop(['C', 'D'], axis=1)

# %%
data.tail()
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 1972116  02/25/2023       8:30   BROOKLYN  11208.0  40.668503 -73.869255
# 1972117  02/24/2023       8:00  MANHATTAN  10023.0  40.776897 -73.975464
# 1972118  02/12/2023      16:25   BROOKLYN  11220.0  40.645580 -74.018684
# 1972119  02/15/2023      11:00     QUEENS  11103.0  40.770233 -73.915620
# 1972120  02/25/2023       5:00   BROOKLYN  11229.0  40.600900 -73.948770
#
#                         LOCATION     ON STREET NAME CROSS STREET NAME  \
# 1972116  (40.668503, -73.869255)   LINDEN BOULEVARD       PINE STREET
# 1972117  (40.776897, -73.975464)  CENTRAL PARK WEST    WEST 73 STREET
# 1972118   (40.64558, -74.018684)                NaN               NaN
# 1972119   (40.770233, -73.91562)                NaN               NaN
# 1972120     (40.6009, -73.94877)                NaN               NaN
#
#                      OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %%
data.describe()
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.746093e+06  1.746093e+06               1.972103e+06
# mean   4.062826e+01 -7.375330e+01               2.963248e-01
# std    1.976256e+00  3.722637e+00               6.873493e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066798e+01 -7.397499e+01               0.000000e+00
# 50%    4.072123e+01 -7.392737e+01               0.000000e+00
# 75%    4.076944e+01 -7.386660e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              1.972090e+06                   1.972121e+06
# mean               1.412207e-03                   5.449919e-02
# std                3.959050e-02                   2.398852e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# ...

# %%
# Correlation matrix
correlation_matrix = data.corr()
print(correlation_matrix)
# Out:
#                                LATITUDE  LONGITUDE  NUMBER OF PERSONS INJURED  \
# LATITUDE                       1.000000  -0.961877                  -0.008562
# LONGITUDE                     -0.961877   1.000000                   0.009035
# NUMBER OF PERSONS INJURED     -0.008562   0.009035                   1.000000
# NUMBER OF PERSONS KILLED      -0.001034   0.001081                   0.015593
# NUMBER OF PEDESTRIANS INJURED -0.004104   0.004367                   0.280389
# NUMBER OF PEDESTRIANS KILLED  -0.001774   0.001747                   0.002515
# NUMBER OF CYCLIST INJURED     -0.004777   0.004086                   0.173516
# NUMBER OF CYCLIST KILLED       0.000476  -0.000482                  -0.000669
# NUMBER OF MOTORIST INJURED    -0.005339   0.005944                   0.907053
# NUMBER OF MOTORIST KILLED      0.000082   0.000027                   0.021276
# COLLISION_ID                  -0.038228   0.037738                   0.050735
#
# ...

# %%
# Data preprocessing

# Convert 'CRASH DATE' column to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# %%
# Data visualization

# Visualize the number of crashes over time
plt.figure(figsize=(12, 6))
data['CRASH DATE'].value_counts().sort_index().plot()
plt.title('Number of Crashes Over Time')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# %%
# Visualize the number of crashes in each borough
plt.figure(figsize=(10, 6))
sns.countplot(x='BOROUGH', data=df)
plt.title('Number of Crashes by Borough')
plt.xlabel('Borough')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Visualize the contributing factors for vehicle crashes
plt.figure(figsize=(12, 8))
sns.countplot(x='CONTRIBUTING FACTOR VEHICLE 1', data=data, order=data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().index)
plt.title('Contributing Factors for Vehicle Crashes')
plt.xlabel('Contributing Factor')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
# Visualize the distribution of injuries and deaths
injury_cols = ['NUMBER OF PERSONS INJURED', 'NUMBER OF PEDESTRIANS INJURED',
               'NUMBER OF CYCLIST INJURED', 'NUMBER OF MOTORIST INJURED']
death_cols = ['NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS KILLED',
              'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST KILLED']

plt.figure(figsize=(10, 6))
data[injury_cols].sum().plot(kind='bar', color='y', label='Injured')
data[death_cols].sum().plot(kind='bar', color='r', label='Killed')
plt.title('Total Injuries and Deaths')
plt.xlabel('Type')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
# Visualize the most common contributing factors for crashes
plt.figure(figsize=(10, 6))
top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)
sns.barplot(x=top_factors.values, y=top_factors.index, color='b')
plt.title('Top Contributing Factors for Crashes')
plt.xlabel('Count')
plt.ylabel('Contributing Factor')
plt.show()

# %%
# Plot the crashes on a scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(df['LONGITUDE'], df['LATITUDE'], c='red', alpha=0.5, s=20)
plt.title('Crash Locations in New York City')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
# Visualize the distribution of crashes by time of day
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'])
data['HOUR'] = data['CRASH TIME'].dt.hour

plt.figure(figsize=(10, 6))
sns.histplot(data['HOUR'], bins=24, kde=True)
plt.title('Distribution of Crashes by Time of Day')
plt.xlabel('Hour')
plt.ylabel('Count')
plt.xticks(range(24))
plt.show()

# %%
# Visualize the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_vehicle_types.values, y=top_vehicle_types.index, color='b')
plt.title('Top Vehicle Types Involved in Crashes')
plt.xlabel('Count')
plt.ylabel('Vehicle Type')
plt.show()

# %%
# Visualize the correlation matrix of numeric columns
numeric_columns = ['NUMBER OF PERSONS INJURED', 'NUMBER OF PERSONS KILLED',
                   'NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED',
                   'NUMBER OF CYCLIST INJURED', 'NUMBER OF CYCLIST KILLED',
                   'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED']

numeric_data = data[numeric_columns]

plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of Numeric Columns')
plt.show()

# %% [markdown]
# Some insights that can be derived from the provided data analysis code:
#
# 1. Number of Crashes Over Time: The line plot depicting the number of crashes over time provides an overview of the trend and pattern of accidents. It can help identify any significant changes or seasonal variations in crash frequency.
#
# 2. Number of Crashes by Borough: The bar plot shows the distribution of crashes across different boroughs. It allows us to compare the number of accidents in each borough and identify areas with higher or lower crash rates.
#
# 3. Total Injuries and Deaths: The bar plot comparing the total number of injuries and deaths provides an understanding of the severity of accidents. It shows the count of injured and killed individuals, differentiating between pedestrians, cyclists, motorists, and overall persons involved in accidents.
#
# 4. Top Contributing Factors for Crashes: The bar plot presents the most common contributing factors for crashes. It helps identify the primary reasons behind accidents and can assist in targeted interventions and policy improvements.
#
# 5. Geographic Distribution of Crashes: The scatter plot visualizes the geographical distribution of accidents using latitude and longitude coordinates. It provides insights into areas with higher crash densities and allows for the identification of hotspots or patterns related to specific boroughs.
#
# 6. Distribution of Crashes by Time of Day: The histogram reveals the distribution of crashes throughout the day. It helps identify peak hours or time periods with higher accident rates, allowing for the implementation of appropriate safety measures during those times.
#
# 7. Top Vehicle Types Involved in Crashes: The bar plot displays the most frequently involved vehicle types in accidents. This information can be valuable for understanding the types of vehicles that are more prone to accidents and may require additional safety measures or awareness campaigns.
#
# 8. Correlation Matrix of Numeric Columns: The correlation heatmap provides an overview of the relationships between various numeric columns related to injuries and fatalities. It helps identify any significant correlations between different factors and provides insights into the impact of specific factors on crash severity.
#
#
# These insights can guide decision-making processes, help identify areas for improvement in road safety measures, and support efforts to reduce the number of accidents and their associated impacts.
